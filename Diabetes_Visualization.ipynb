# %%
#import required packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(color_codes=True)

# %%
#load data set
diabetes=pd.read_csv('diabetes.csv')

# %%
#Get details about dataset or the overview of data
diabetes.head(30)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 1             1       85             66             29        0  26.6
# 2             8      183             64              0        0  23.3
# 3             1       89             66             23       94  28.1
# 4             0      137             40             35      168  43.1
# 5             5      116             74              0        0  25.6
# 6             3       78             50             32       88  31.0
# 7            10      115              0              0        0  35.3
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
# ...

# %%
pd.crosstab(diabetes['SkinThickness'], diabetes['Outcome'])
# Out:
# Outcome          0   1
# SkinThickness
# 0              139  88
# 7                1   1
# 8                2   0
# 10               5   0
# 11               6   0
# 12               6   1
# 13              10   1
# 14               4   2
# 15              13   1
# 16               6   0
# 17              12   2
# 18              16   4
# 19              15   3
# 20              11   2
# 21               8   2
# 22              12   4
# 23              18   4
# 24               6   6
# 25              11   5
# 26              10   6
# 27              16   7
# 28              15   5
# 29              10   7
# 30              18   9
# 31              13   6
# 32              17  14
# 33              11   9
# 34               5   3
# 35               7   8
# 36               6   8
# 37               8   8
# 38               5   2
# 39              10   8
# 40              11   5
# 41               8   7
# 42               5   6
# 43               4   2
# 44               2   3
# ...

# %%
pd.crosstab(diabetes['Pregnancies'], diabetes['Outcome'])
# Out:
# Outcome        0   1
# Pregnancies
# 0             73  38
# 1            106  29
# 2             84  19
# 3             48  27
# 4             45  23
# 5             36  21
# 6             34  16
# 7             20  25
# 8             16  22
# 9             10  18
# 10            14  10
# 11             4   7
# 12             5   4
# 13             5   5
# 14             0   2
# 15             0   1
# 17             0   1

# %%
#To check number of rows,columns,total entries and data type
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
#To see if any null value exists
diabetes.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#to check all the five points, mean, std and total count
diabetes.describe()
#From below details we can analyse that there is some mistake in data as attributes like(Glucose)
#,BloodPressure, SkinThickness, Insulin BMI) can never be zero in a normal human body.
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
#To find median for the attribute Pregnancies
diabetes['Pregnancies'].median()
# Out:
# 3.0

# %%
#To find mode for the attribute Pregnancies
diabetes['Pregnancies'].mode()
# Out:
# 0    1
# dtype: int64

# %%
#To find median for the attribute Glucose
diabetes['Glucose'].median()
# Out:
# 117.0

# %%
#To find mode for the attribute Glucose
diabetes['Glucose'].mode()
# Out:
# 0     99
# 1    100
# dtype: int64

# %%
#To find median for the attribute BloodPressure
diabetes['BloodPressure'].median()
# Out:
# 72.0

# %%
#To find mode for the attribute BloodPressure
diabetes['BloodPressure'].mode()
# Out:
# 0    70
# dtype: int64

# %%
#To find median for the attribute SkinThickness
diabetes['SkinThickness'].median()
# Out:
# 23.0

# %%
#To find mode for the attribute SkinThickness
diabetes['SkinThickness'].mode()
# Out:
# 0    0
# dtype: int64

# %%
#To find median for the attribute Insulin
diabetes['Insulin'].median()
# Out:
# 30.5

# %%
#To find mode for the attribute Insulin
diabetes['Insulin'].mode()
# Out:
# 0    0
# dtype: int64

# %%
#To find median for the attribute BMI
diabetes['BMI'].median()
# Out:
# 32.0

# %%
#To find mode for the attribute BMI
diabetes['BMI'].mode()
# Out:
# 0    32.0
# dtype: float64

# %%
#To find median for the attribute DiabetesPedigreeFunction
diabetes['DiabetesPedigreeFunction'].median()
# Out:
# 0.3725

# %%
#To find mode for the attribute DiabetesPedigreeFunction
diabetes['DiabetesPedigreeFunction'].mode()
# Out:
# 0    0.254
# 1    0.258
# dtype: float64

# %%
#To find median for the attribute Age
diabetes['Age'].median()
# Out:
# 29.0

# %%
#To find mode for the attribute Age
diabetes['Age'].mode()
# Out:
# 0    22
# dtype: int64

# %%
#To find mode of attribute Outcome
diabetes['Outcome'].mode()
#So we can conclude that non-diabetic people are more.
# Out:
# 0    0
# dtype: int64

# %%
#histogram for attribute Pregnancies
sns.distplot(diabetes['Pregnancies'], kde=True, rug=True)
#From the below graph we can conclude that maximum of people or samples comes under 0 and 1 pregnancies 
#so we can tell that there are maximum women with zero and 1 pregnancy.

# %%
#histogram for attribute Glucose
sns.distplot(diabetes['Glucose'], kde=True, rug=True)

# %%
#histogram for attribute BloodPressure
sns.distplot(diabetes['BloodPressure'], kde=True, rug=True)
#From the below graph we can conclude that no one can have bloodpressure as "zero" and maximum people ranges
#bloodpressure from 70 to 80

# %%
#histogram for attribute SkinThickness
sns.distplot(diabetes['SkinThickness'], kde=True, rug=True)
#From the below graph we can see that maximum people are with zero thickness of skin which is not possible.

# %%
#histogram for attribute Insulin
sns.distplot(diabetes['Insulin'], kde=True, rug=True)
#Ideally insulin content in human body should be 3 but it can not go to "zero", data set tells us that maximum
#people have insulin level as zero which need to be checked once.

# %%
#histogram for attribute BMI
sns.distplot(diabetes['BMI'], kde=True, rug=True)
#again BMI level in human body can never be zero so need to check that, 
#and we can observe that maximum people are having BMI between 30-40

# %%
#histogram for attribute DiabetesPedigreeFunction
sns.distplot(diabetes['DiabetesPedigreeFunction'], kde=True, rug=True)

# %%
#histogram for attribute Age
sns.distplot(diabetes['Age'], kde=True, rug=True)

# %%
diabetes['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
sns.countplot(diabetes['Outcome'])
#from the below we can see that 500 cases are negative it means they are non diabetic and 268 are
#positive it means diabetic.

# %%
sns.stripplot(diabetes['Pregnancies'],diabetes['Age'], jitter=True)

# %%
sns.stripplot(diabetes['Pregnancies'],diabetes['BloodPressure'], jitter=True)

# %%
sns.countplot(diabetes['Pregnancies'], hue=diabetes['Outcome'])
#From below figure we can coclude that maximum number of women who are not pregnant have a positive result.

# %%
diabetes['Age'].value_counts()
# Out:
# 22    72
# 21    63
# 25    48
# 24    46
# 23    38
# 28    35
# 26    33
# 27    32
# 29    29
# 31    24
# 41    22
# 30    21
# 37    19
# 42    18
# 33    17
# 32    16
# 36    16
# 38    16
# 45    15
# 34    14
# 40    13
# 43    13
# 46    13
# 39    12
# 35    10
# 50     8
# 44     8
# 51     8
# 52     8
# 58     7
# 47     6
# 54     6
# 57     5
# 60     5
# 48     5
# 49     5
# 53     5
# 55     4
# 62     4
# 63     4
# 66     4
# 56     3
# 59     3
# 65     3
# 67     3
# 61     2
# 69     2
# 72     1
# 64     1
# 68     1
# 70     1
# 81     1
# Name: Age, dtype: int64

# %%
sns.boxplot(diabetes['Pregnancies'],diabetes['Age'], hue=diabetes['Outcome'])

# %%
sns.scatterplot(x="Insulin", y="Glucose", data=diabetes)

# %%
sns.scatterplot(x="BloodPressure", y="Glucose", data=diabetes)

# %%
sns.scatterplot(x="Insulin", y="BloodPressure", data=diabetes)

# %%
sns.scatterplot(x="Insulin", y="Age", data=diabetes)

# %%
sns.factorplot(x="Pregnancies",
              y="BMI",
              hue="Outcome",
              data=diabetes,
              kind="bar")
# Out:
# C:\Users\Asus\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x="Pregnancies",
              y="BMI",
              hue="Outcome",
              data=diabetes,
              kind="swarm")
# Out:
# C:\Users\Asus\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x="Pregnancies",
              y="BMI",
              hue="Outcome",
              data=diabetes,
              kind="box")
# Out:
# C:\Users\Asus\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.swarmplot(diabetes['Pregnancies'],diabetes['BloodPressure'], hue=diabetes['Outcome'])

# %%
sns.swarmplot(diabetes['Pregnancies'], diabetes['Insulin'], hue=diabetes['Outcome'])

# %%
sns.swarmplot(diabetes['Pregnancies'], diabetes['Glucose'], hue=diabetes['Outcome'])

# %%
sns.pointplot(diabetes['Pregnancies'], diabetes['BloodPressure'], hue=diabetes['Outcome'])

# %%
sns.barplot(diabetes['Pregnancies'], diabetes['BloodPressure'], hue=diabetes['Outcome'])
#From below graph we can tell that women who were pregnant for more than 13 times have more chance
# of having diabetes

# %%
sns.barplot(diabetes['Pregnancies'], diabetes['Age'], hue=diabetes['Outcome'])

# %%
#we can plot heatmap to see the co-relation among all the attributes
corr=diabetes.corr()
corr
sns.heatmap(corr, annot=True)

# %%
sns.boxplot(diabetes['Age'], color="red")

# %%
sns.boxplot(diabetes['Pregnancies'], color="pink")

# %%
sns.boxplot(diabetes['Glucose'], color="pink")

# %%
sns.boxplot(diabetes['BloodPressure'], color="pink")

# %%
sns.boxplot(diabetes['Insulin'], color="pink")

# %%
sns.boxplot(diabetes['SkinThickness'], color="pink")

# %%
sns.boxplot(diabetes['BMI'], color="pink")

# %%
sns.boxplot(diabetes['DiabetesPedigreeFunction'], color="yellow")

# %%
sns.violinplot(x="Outcome", y="BMI", data=diabetes)

# %%
sns.violinplot(x="Pregnancies", y="BMI", data=diabetes)

# %%
sns.violinplot(x="Pregnancies", y="Age", data=diabetes)

# %%
sns.violinplot(x="Outcome", y="Age", data=diabetes)

# %%
sns.pairplot(diabetes, hue='Outcome', palette="husl")
# Out:
# C:\Users\Asus\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\Asus\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
from sklearn import linear_model

# %%
regr = linear_model.LinearRegression()
y=diabetes['Pregnancies']
x=diabetes[['Glucose']]
regr.fit(x,y)
regr.coef_ , regr.intercept_
# Out:
# (array([0.01364358]), 2.1956174006693345)

# %%
#Pregnancies= 2.195617400669334*Glucose + 0.01364358

# %% [markdown]
# * After investigating the dataset and performing EDA on it, i can tell that out of 768 records 268 are posetive that is 34.9% of data and rest 500 that is 65.1% of records are negative or non-diabetic.
# * There are attributes where the values or figures which are collected are not correct as we have "zero" figures in attributes (Glucose, Insulin, BMI, BloodPressure, SkinThickness) which can not be true.
# * Maximum number of records who are suffering for diabetes are not pregnant(Out of all the posetive cases)
# * When i examined Age attribute then i figured out that maximum people have a age range of 22 to 35 who are having positive case of diabetes.
# *I have used scatter plot, heatmap and pair plot to determine the relationship between attributes
# *Attribute like pregnancies have right-skewed curve, Glucose have bell-curve, BloodPressure have bell-curve, SkinThickness have right-skewed curve, Insulin have right-skewed curve, BMI have bell-curve, Diabetes Pedigere function have right-skewed curve, Age have right-skewed curve
# *To calculate diabetes in more accurate way "urine test" should also be added as one of the attribute in data set and in most of the attributes outliers are present.
# *Finally i used LinearRegression to find the formula of line i.e y=mx+c.
